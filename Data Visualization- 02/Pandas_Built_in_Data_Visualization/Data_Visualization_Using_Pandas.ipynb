# %% [markdown]
# # Pandas Built-in Data Visualization
#
# Hi Guys,<br>
# Welcome to [pandas for Data Visualization](https://pandas.pydata.org/pandas-docs/stable/visualization.html) now. In the Data Analysis section, we have explored the power of pandas for data analysis. Let's talk about pandas built-in data visualization capabilities. We can create decent looking plots using pandas. This is actually built on matplotlib and embedded into pandas for quick use. <br>
#
# Let's take a look!
# ### Histograms
# ### Area plot
# ### Bar plots
# ### Line plots
# ### Scatter plots
# ### BoxPlots
# ### Pie Plot

# %%
# let's do some imports first
import numpy as np
import pandas as pd

# %% [markdown]
# Let's create some random datasets now! <br>
# df1 with date as index and df2 with sequential index.
#
# *Although, we can use seaborn built-in datasets as well. To make this lecture as a separate and independent, I am creating new data frames here to use.*

# %%
#We can use date_range function from pandas
# periods = 500, no of periods (days) to generate
dates = pd.date_range('1/1/2023', periods=500)
dates
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10',
#                ...
#                '2024-05-05', '2024-05-06', '2024-05-07', '2024-05-08',
#                '2024-05-09', '2024-05-10', '2024-05-11', '2024-05-12',
#                '2024-05-13', '2024-05-14'],
#               dtype='datetime64[ns]', length=500, freq='D')

# %%
# Let's use numpy's randn for "standard normal" distribution
data1 = np.random.randn(500,3) #(500,3) to tell the shape we want
data1

#randn --- normal distribution
# Out:
# array([[-0.81362945,  0.5084207 ,  1.53481696],
#        [ 2.38286234, -0.6322101 , -1.17319307],
#        [-1.55359188,  0.94662472, -0.09603469],
#        ...,
#        [ 0.29404937, -0.88359   , -1.60891566],
#        [ 1.13068726, -0.24925429,  0.26464598],
#        [ 1.0171682 , -0.02915379,  1.26618612]])

# %%
# randn(1000,4) 1000 by 4 2D array
df1 = pd.DataFrame(data = data1, index=dates, columns=['A', 'B', 'C'])

# %%
df1
# Out:
#                    A         B         C
# 2023-01-01 -0.813629  0.508421  1.534817
# 2023-01-02  2.382862 -0.632210 -1.173193
# 2023-01-03 -1.553592  0.946625 -0.096035
# 2023-01-04  0.888736 -0.130748 -0.073049
# 2023-01-05  0.301011  0.130455  0.263314
# ...              ...       ...       ...
# 2024-05-10 -1.198497  0.373546 -0.629952
# 2024-05-11  0.154540 -0.411931 -0.169295
# 2024-05-12  0.294049 -0.883590 -1.608916
# 2024-05-13  1.130687 -0.249254  0.264646
# 2024-05-14  1.017168 -0.029154  1.266186
#
# [500 rows x 3 columns]

# %%
# Let's generate a series using rand()
df1['D'] = np.random.rand(500)

#rand ---- no normal distribution

# %%
df1
# Out:
#                    A         B         C         D
# 2023-01-01 -0.813629  0.508421  1.534817  0.234244
# 2023-01-02  2.382862 -0.632210 -1.173193  0.053996
# 2023-01-03 -1.553592  0.946625 -0.096035  0.781073
# 2023-01-04  0.888736 -0.130748 -0.073049  0.855244
# 2023-01-05  0.301011  0.130455  0.263314  0.219656
# ...              ...       ...       ...       ...
# 2024-05-10 -1.198497  0.373546 -0.629952  0.483836
# 2024-05-11  0.154540 -0.411931 -0.169295  0.693103
# 2024-05-12  0.294049 -0.883590 -1.608916  0.639814
# 2024-05-13  1.130687 -0.249254  0.264646  0.438465
# 2024-05-14  1.017168 -0.029154  1.266186  0.076885
#
# [500 rows x 4 columns]

# %%
# rand(20,3) 20 by 3 2D array
data2 = np.random.rand(20,3)
col = ['X', 'Y', 'Z']
df2 = pd.DataFrame(data = data2, columns=col)

# %%
df2
# Out:
#            X         Y         Z
# 0   0.436673  0.600825  0.051998
# 1   0.780931  0.421565  0.762842
# 2   0.232558  0.176444  0.357667
# 3   0.946556  0.441970  0.477760
# 4   0.170051  0.787197  0.569409
# 5   0.172148  0.175701  0.104905
# 6   0.174309  0.990401  0.983400
# 7   0.937153  0.811433  0.284497
# 8   0.361436  0.750253  0.510920
# 9   0.369873  0.823470  0.118025
# 10  0.442585  0.528951  0.884732
# 11  0.086364  0.204359  0.203403
# 12  0.419954  0.334403  0.211639
# 13  0.290849  0.587802  0.917338
# 14  0.522236  0.814933  0.391710
# 15  0.366266  0.617027  0.718516
# 16  0.634885  0.138864  0.844820
# 17  0.469300  0.219124  0.399510
# 18  0.752289  0.157294  0.003818
# 19  0.989198  0.240034  0.555428

# %%
df1['A'].hist()
# Out:
# <Axes: >

# %%
df2['X'].hist()
# Out:
# <Axes: >

# %%
df1['A'].hist(edgecolor='black')
# Out:
# <Axes: >

# %%
df1['A'].hist(bins=30,edgecolor='black',figsize=(12,5))
# Out:
# <Axes: >

# %%
# we can also plot using kind
df1['A'].plot(kind='hist',bins=30, edgecolor='black',figsize=(12,5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(kind='hist',bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['D'].plot(kind='hist',bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Style Sheets
#
# Matplotlib has [style sheets](http://matplotlib.org/gallery.html#style_sheets). We can use this to make our plots look a little nicer. These style sheets include `plot_bmh`,`plot_fivethirtyeight`,`plot_ggplot` and more. They basically create a set of style rules that our plots follow. Its good to use them because they make all our plots to have the same look and feel more professional. <br>
# Let's call the style first!

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')

# %%
df1['A'].hist(bins=30)
# Out:
# <Axes: >

# %%
# Lets use another style "bmh"
plt.style.use('bmh')
df1['A'].hist(bins=50)
# Out:
# <Axes: >

# %%
# we can use dark_background 
plt.style.use('dark_background')
df1['A'].hist(bins=50)
# Out:
# <Axes: >

# %%
# another example
plt.style.use('fivethirtyeight')
df1['A'].hist(bins=50)
# Out:
# <Axes: >

# %%
plt.style.use('dark_background')
df2['X'].plot(kind='hist', bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Plot Types
#
# There are several plot types built-in to pandas, most of them are statistical plots by nature:
#
# * `df.plot.area`
# * `df.plot.bar`
# * `df.plot.barh`
# * `df.plot.hist`
# * `df.plot.line`
# * `df.plot.scatter`
# * `df.plot.box`
# * `df.plot.pie`
#
# We can also just call `df.plot(kind='hist')` or replace that kind argument with any of the key terms shown in the list above (e.g. `'box','barh'`, etc..)<br>
# **Let's go through these plots one-by-one using our data frames `df1` and `df2`!**

# %% [markdown]
# ### Area plot

# %%
df2
# Out:
#            X         Y         Z
# 0   0.436673  0.600825  0.051998
# 1   0.780931  0.421565  0.762842
# 2   0.232558  0.176444  0.357667
# 3   0.946556  0.441970  0.477760
# 4   0.170051  0.787197  0.569409
# 5   0.172148  0.175701  0.104905
# 6   0.174309  0.990401  0.983400
# 7   0.937153  0.811433  0.284497
# 8   0.361436  0.750253  0.510920
# 9   0.369873  0.823470  0.118025
# 10  0.442585  0.528951  0.884732
# 11  0.086364  0.204359  0.203403
# 12  0.419954  0.334403  0.211639
# 13  0.290849  0.587802  0.917338
# 14  0.522236  0.814933  0.391710
# 15  0.366266  0.617027  0.718516
# 16  0.634885  0.138864  0.844820
# 17  0.469300  0.219124  0.399510
# 18  0.752289  0.157294  0.003818
# 19  0.989198  0.240034  0.555428

# %%
df2.plot.scatter(x='X',y='Y')
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %%
df2['X'].plot()
# Out:
# <Axes: >

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df2['X'].plot(kind='area')
# Out:
# <Axes: >

# %%
df2.plot.area()
# Out:
# <Axes: >

# %% [markdown]
# ### Bar plots

# %%
df2
# Out:
#            X         Y         Z
# 0   0.436673  0.600825  0.051998
# 1   0.780931  0.421565  0.762842
# 2   0.232558  0.176444  0.357667
# 3   0.946556  0.441970  0.477760
# 4   0.170051  0.787197  0.569409
# 5   0.172148  0.175701  0.104905
# 6   0.174309  0.990401  0.983400
# 7   0.937153  0.811433  0.284497
# 8   0.361436  0.750253  0.510920
# 9   0.369873  0.823470  0.118025
# 10  0.442585  0.528951  0.884732
# 11  0.086364  0.204359  0.203403
# 12  0.419954  0.334403  0.211639
# 13  0.290849  0.587802  0.917338
# 14  0.522236  0.814933  0.391710
# 15  0.366266  0.617027  0.718516
# 16  0.634885  0.138864  0.844820
# 17  0.469300  0.219124  0.399510
# 18  0.752289  0.157294  0.003818
# 19  0.989198  0.240034  0.555428

# %%
df2['X'].plot.bar(figsize=(15,5))
# Out:
# <Axes: >

# %%
df2.plot.bar(figsize=(15,5))
# Out:
# <Axes: >

# %%
# Horizontal bars
df2.plot.barh(figsize=(10,10))
# Out:
# <Axes: >

# %%
df2
# Out:
#            X         Y         Z
# 0   0.436673  0.600825  0.051998
# 1   0.780931  0.421565  0.762842
# 2   0.232558  0.176444  0.357667
# 3   0.946556  0.441970  0.477760
# 4   0.170051  0.787197  0.569409
# 5   0.172148  0.175701  0.104905
# 6   0.174309  0.990401  0.983400
# 7   0.937153  0.811433  0.284497
# 8   0.361436  0.750253  0.510920
# 9   0.369873  0.823470  0.118025
# 10  0.442585  0.528951  0.884732
# 11  0.086364  0.204359  0.203403
# 12  0.419954  0.334403  0.211639
# 13  0.290849  0.587802  0.917338
# 14  0.522236  0.814933  0.391710
# 15  0.366266  0.617027  0.718516
# 16  0.634885  0.138864  0.844820
# 17  0.469300  0.219124  0.399510
# 18  0.752289  0.157294  0.003818
# 19  0.989198  0.240034  0.555428

# %%
# we can stack them on top of each other 
df2.plot.bar(stacked=True, figsize=(10,5))
# Out:
# <Axes: >

# %%
df1
# Out:
#                    A         B         C         D
# 2023-01-01 -0.813629  0.508421  1.534817  0.234244
# 2023-01-02  2.382862 -0.632210 -1.173193  0.053996
# 2023-01-03 -1.553592  0.946625 -0.096035  0.781073
# 2023-01-04  0.888736 -0.130748 -0.073049  0.855244
# 2023-01-05  0.301011  0.130455  0.263314  0.219656
# ...              ...       ...       ...       ...
# 2024-05-10 -1.198497  0.373546 -0.629952  0.483836
# 2024-05-11  0.154540 -0.411931 -0.169295  0.693103
# 2024-05-12  0.294049 -0.883590 -1.608916  0.639814
# 2024-05-13  1.130687 -0.249254  0.264646  0.438465
# 2024-05-14  1.017168 -0.029154  1.266186  0.076885
#
# [500 rows x 4 columns]

# %%
df1.plot.scatter(x='A', y='B', figsize=(12,3))
plt.show()

# %%
df1.plot.scatter(x='A', y='B', figsize=(12,3))
#plt.show()
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot(x='A', y='B',figsize=(12,3))
# Out:
# <Axes: xlabel='A'>

# %%
df1.plot(x='A', y='B',figsize=(12,3),lw=.5)
# Out:
# <Axes: xlabel='A'>

# %%
df1.plot.line(x='A', y='B',figsize=(12,3))
# Out:
# <Axes: xlabel='A'>

# %%
df1.plot.line(x='A', y='B',figsize=(12,3),lw=.5)
# Out:
# <Axes: xlabel='A'>

# %%
df1.plot.scatter(x='A', y='B', c='0.2', cmap='coolwarm', figsize=(12,3))
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1258: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='A', ylabel='B'>

# %% [markdown]
# The keyword c may be given as the name of a column to provide colors for each point. cmap can be used to indicate colormap.
# For all the colormaps, click here

# %%
df1
# Out:
#                    A         B         C         D
# 2023-01-01 -0.813629  0.508421  1.534817  0.234244
# 2023-01-02  2.382862 -0.632210 -1.173193  0.053996
# 2023-01-03 -1.553592  0.946625 -0.096035  0.781073
# 2023-01-04  0.888736 -0.130748 -0.073049  0.855244
# 2023-01-05  0.301011  0.130455  0.263314  0.219656
# ...              ...       ...       ...       ...
# 2024-05-10 -1.198497  0.373546 -0.629952  0.483836
# 2024-05-11  0.154540 -0.411931 -0.169295  0.693103
# 2024-05-12  0.294049 -0.883590 -1.608916  0.639814
# 2024-05-13  1.130687 -0.249254  0.264646  0.438465
# 2024-05-14  1.017168 -0.029154  1.266186  0.076885
#
# [500 rows x 4 columns]

# %%
df1.plot.scatter(x='A',y='B', c='D', cmap='coolwarm', figsize=(12,3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
# We can use 's' to indicate size
df1.plot.scatter(x='A', y='B', s=90,  figsize=(12,3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
# We can use 's' to indicate size
df1.plot.scatter(x='A', y='B', s=df1['D']*100,  figsize=(12,3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.hexbin(x='A',y='B', gridsize=30, cmap='Oranges',  figsize=(12,3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %% [markdown]
# ### Line plots

# %%
gas = pd.read_csv('2024-05-05T17-02-41.624Z-gas_prices.csv')
gas
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# 13  2003       2.19    1.99    4.35     4.59   4.53   3.47    2.04
# 14  2004       2.72    2.37    4.99     5.24   5.29   3.93    2.03
# 15  2005       3.23    2.89    5.46     5.66   5.74   4.28    2.22
# 16  2006       3.54    3.26    5.88     6.03   6.10   4.47    2.31
# 17  2007       3.85    3.59    6.60     6.88   6.73   4.49    2.40
# 18  2008       4.45    4.08    7.51     7.75   7.63   5.74    2.45
#
#     South Korea    UK   USA
# 0          2.05  2.82  1.16
# 1          2.49  3.01  1.14
# 2          2.65  3.06  1.13
# 3          2.88  2.84  1.11
# 4          2.87  2.99  1.11
# 5          2.94  3.21  1.15
# 6          3.18  3.34  1.23
# 7          3.34  3.83  1.23
# 8          3.04  4.06  1.06
# 9          3.80  4.29  1.17
# 10         4.18  4.58  1.51
# 11         3.76  4.13  1.46
# 12         3.84  4.16  1.36
# 13         4.11  4.70  1.59
# 14         4.51  5.56  1.88
# 15         5.28  5.97  2.30
# 16         5.92  6.36  2.59
# 17         6.21  7.13  2.80
# 18         5.83  7.42  3.27

# %% [markdown]
# ### Using Pandas

# %%
gas['UK'].plot(xticks=gas.index[::3])
# Out:
# <Axes: >

# %%
gas['UK'].plot()
# Out:
# <Axes: >

# %%
gas.plot(x='Year', y='UK')
# Out:
# <Axes: xlabel='Year'>

# %%
gas.Year[::3].tolist()
# Out:
# [1990, 1993, 1996, 1999, 2002, 2005, 2008]

# %%
gas.plot(x='Year', y='UK', xticks=gas.Year[::3].tolist())
# Out:
# <Axes: xlabel='Year'>

# %%
gas.plot(x='Year', y='UK', xticks=gas.Year[::3].tolist())
gas.plot(x='Year', y='USA', xticks=gas.Year[::3].tolist())
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# ### Using Pyplot

# %%
plt.subplots(figsize=(10,5))
plt.plot(gas['Year'], gas['USA'],label="USA")
plt.plot(gas['Year'], gas['Canada'],label="Canada")
plt.xticks(gas.Year[::3].tolist())
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.style.use('bmh')
plt.title('Gas Prices over Time (in USD)', fontdict={'fontweight':'bold', 'fontsize': 18, 'color':'g'})

plt.plot(gas.Year, gas.USA, 'b.-', label='USA')
plt.plot(gas.Year, gas['Canada'], 'r.-', label='Canada')
plt.plot(gas.Year, gas['South Korea'], 'g.-', label='SKorea')
plt.plot(gas.Year, gas.Australia, 'y.-', label='Australia')

plt.xticks(gas.Year[::3].tolist()) #[1990, 1993, 1996, 1999, 2002, 2005, 2008]

plt.xlabel('Year')
plt.ylabel('US Dollars')


plt.legend()
plt.show()

# %%
df1
# Out:
#                    A         B         C         D
# 2023-01-01 -0.813629  0.508421  1.534817  0.234244
# 2023-01-02  2.382862 -0.632210 -1.173193  0.053996
# 2023-01-03 -1.553592  0.946625 -0.096035  0.781073
# 2023-01-04  0.888736 -0.130748 -0.073049  0.855244
# 2023-01-05  0.301011  0.130455  0.263314  0.219656
# ...              ...       ...       ...       ...
# 2024-05-10 -1.198497  0.373546 -0.629952  0.483836
# 2024-05-11  0.154540 -0.411931 -0.169295  0.693103
# 2024-05-12  0.294049 -0.883590 -1.608916  0.639814
# 2024-05-13  1.130687 -0.249254  0.264646  0.438465
# 2024-05-14  1.017168 -0.029154  1.266186  0.076885
#
# [500 rows x 4 columns]

# %% [markdown]
# ## BoxPlots
# To visualize the distribution of values within each column.

# %%
df2
# Out:
#            X         Y         Z
# 0   0.436673  0.600825  0.051998
# 1   0.780931  0.421565  0.762842
# 2   0.232558  0.176444  0.357667
# 3   0.946556  0.441970  0.477760
# 4   0.170051  0.787197  0.569409
# 5   0.172148  0.175701  0.104905
# 6   0.174309  0.990401  0.983400
# 7   0.937153  0.811433  0.284497
# 8   0.361436  0.750253  0.510920
# 9   0.369873  0.823470  0.118025
# 10  0.442585  0.528951  0.884732
# 11  0.086364  0.204359  0.203403
# 12  0.419954  0.334403  0.211639
# 13  0.290849  0.587802  0.917338
# 14  0.522236  0.814933  0.391710
# 15  0.366266  0.617027  0.718516
# 16  0.634885  0.138864  0.844820
# 17  0.469300  0.219124  0.399510
# 18  0.752289  0.157294  0.003818
# 19  0.989198  0.240034  0.555428

# %%
df2['X'].max()
# Out:
# 0.9891979830652982

# %%
df2['X'].min()
# Out:
# 0.08636420344905427

# %%
df2['X'].quantile(0.25)
# Out:
# 0.27627615010606754

# %%
df2['X'].quantile(0.50)
# Out:
# 0.4283136125276725

# %%
df2['X'].quantile(0.75)
# Out:
# 0.6642363922662613

# %%
df2['X'].plot.box()
# Out:
# <Axes: >

# %%
df2['X'].plot.box()
# Out:
# <Axes: >

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df2.plot.box(vert=False)
# Out:
# <Axes: >

# %% [markdown]
# ## Pie Plot
# We can create a pie plot with  `Series.plot.pie()` or `DataFrame.plot.pie()`. If your data includes any NaN, they will be automatically filled with 0. A ValueError will be raised if there are any negative values in your data.<br>
# Let's try pie plot with df2.<br>
#
# We need to specify a target column by the y argument. When y is specified, pie plot of selected column will be drawn.

# %%
df2
# Out:
#            X         Y         Z
# 0   0.436673  0.600825  0.051998
# 1   0.780931  0.421565  0.762842
# 2   0.232558  0.176444  0.357667
# 3   0.946556  0.441970  0.477760
# 4   0.170051  0.787197  0.569409
# 5   0.172148  0.175701  0.104905
# 6   0.174309  0.990401  0.983400
# 7   0.937153  0.811433  0.284497
# 8   0.361436  0.750253  0.510920
# 9   0.369873  0.823470  0.118025
# 10  0.442585  0.528951  0.884732
# 11  0.086364  0.204359  0.203403
# 12  0.419954  0.334403  0.211639
# 13  0.290849  0.587802  0.917338
# 14  0.522236  0.814933  0.391710
# 15  0.366266  0.617027  0.718516
# 16  0.634885  0.138864  0.844820
# 17  0.469300  0.219124  0.399510
# 18  0.752289  0.157294  0.003818
# 19  0.989198  0.240034  0.555428

# %%
# let's take use X column only
df2.plot.pie(y='X', figsize=(12, 10), autopct='%.2f %%')#,figsize=(12, 4),legend=False)
# Out:
# <Axes: ylabel='X'>

# %%
fifa = pd.read_csv('2024-05-05T17-03-15.956Z-fifa_data.csv')
fifa #select * from fifa
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                               ...         ...
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 0      https://cdn.sofifa.org/flags/52.png       94         94
# 1      https://cdn.sofifa.org/flags/38.png       94         94
# 2      https://cdn.sofifa.org/flags/54.png       92         93
# 3      https://cdn.sofifa.org/flags/45.png       91         93
# 4       https://cdn.sofifa.org/flags/7.png       91         92
# ...                                    ...      ...        ...
# 18202  https://cdn.sofifa.org/flags/14.png       47         65
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# 18205  https://cdn.sofifa.org/flags/14.png       47         66
# 18206  https://cdn.sofifa.org/flags/14.png       46         66
#
#                       Club  ... Composure Marking StandingTackle  \
# 0             FC Barcelona  ...      96.0    33.0           28.0
# 1                 Juventus  ...      95.0    28.0           31.0
# 2      Paris Saint-Germain  ...      94.0    27.0           24.0
# 3        Manchester United  ...      68.0    15.0           21.0
# 4          Manchester City  ...      88.0    68.0           58.0
# ...                    ...  ...       ...     ...            ...
# 18202      Crewe Alexandra  ...      45.0    40.0           48.0
# 18203       Trelleborgs FF  ...      42.0    22.0           15.0
# 18204     Cambridge United  ...      41.0    32.0           13.0
# 18205      Tranmere Rovers  ...      46.0    20.0           25.0
# 18206      Tranmere Rovers  ...      43.0    40.0           43.0
#
#        SlidingTackle GKDiving  GKHandling  GKKicking  GKPositioning  \
# 0               26.0      6.0        11.0       15.0           14.0
# 1               23.0      7.0        11.0       15.0           14.0
# 2               33.0      9.0         9.0       15.0           15.0
# 3               13.0     90.0        85.0       87.0           88.0
# 4               51.0     15.0        13.0        5.0           10.0
# ...              ...      ...         ...        ...            ...
# 18202           47.0     10.0        13.0        7.0            8.0
# 18203           19.0     10.0         9.0        9.0            5.0
# 18204           11.0      6.0         5.0       10.0            6.0
# 18205           27.0     14.0         6.0       14.0            8.0
# 18206           50.0     10.0        15.0        9.0           12.0
#
#       GKReflexes Release Clause
# 0            8.0        €226.5M
# 1           11.0        €127.1M
# 2           11.0        €228.1M
# 3           94.0        €138.6M
# 4           13.0        €196.4M
# ...          ...            ...
# 18202        9.0          €143K
# 18203       12.0          €113K
# 18204       13.0          €165K
# 18205        9.0          €143K
# 18206        9.0          €165K
#
# [18207 rows x 89 columns]

# %%
fifa['Weight']
# Out:
# 0        159lbs
# 1        183lbs
# 2        150lbs
# 3        168lbs
# 4        154lbs
#           ...
# 18202    134lbs
# 18203    170lbs
# 18204    148lbs
# 18205    154lbs
# 18206    176lbs
# Name: Weight, Length: 18207, dtype: object

# %%
def stripdata(x):
    if type(x)==str:
        return float(x[0:3])
    else:
        return x

# %%
stripdata('159lbs')
# Out:
# 159.0

# %%
fifa['Weight'] = fifa['Weight'].apply(stripdata)

# %%
fifa['Weight']
# Out:
# 0        159.0
# 1        183.0
# 2        150.0
# 3        168.0
# 4        154.0
#          ...
# 18202    134.0
# 18203    170.0
# 18204    148.0
# 18205    154.0
# 18206    176.0
# Name: Weight, Length: 18207, dtype: float64

# %%
fifa[fifa.Weight < 125].count()[0]
# Out:
# 41

# %%
light = fifa[fifa.Weight < 125].count()[0]
light
# Out:
# 41

# %%
light_medium = fifa[(fifa.Weight >= 125) & (fifa.Weight < 150)].count()[0]
light_medium
# Out:
# 2290

# %%
medium = fifa[(fifa.Weight >= 150) & (fifa.Weight < 175)].count()[0]
medium
# Out:
# 10876

# %%
medium_heavy = fifa[(fifa.Weight >= 175) & (fifa.Weight < 200)].count()[0]
medium_heavy
# Out:
# 4583

# %%
heavy = fifa[fifa.Weight >= 200].count()[0]
heavy
# Out:
# 369

# %%
weights = [light,light_medium, medium, medium_heavy, heavy]
weights
# Out:
# [41, 2290, 10876, 4583, 369]

# %%
plt.figure(figsize=(10,10))

label = ['under 125', '125-150', '150-175', '175-200', 'over 200']

plt.pie(weights, labels=label, autopct='%.2f %%',  pctdistance=0.8)

plt.legend(title="Weight Range")

plt.show()

# %%
plt.figure(figsize=(10,10))

label = ['under 125', '125-150', '150-175', '175-200', 'over 200']

explode = [.4,.2,0,0,.4]

plt.pie(weights, labels=label, explode=explode, autopct='%.2f %%',  pctdistance=0.8)

plt.legend(title="Weight Range")

plt.show()

# %% [markdown]
# This was all about the data visualization using pandas. You can see that how convenient it is to use pandas data visualization capabilities while EDA. It balances ease of use with control over the figure. A lot of the plot calls also accept additional arguments of their parent matplotlib library call. <br>
#
# Let's move on to the exercises section now, where we will try to solve some tasks related to pandas data visualization. See you in the next lecture, Good Luck!
#
# # Great Job!
